# %%
import numpy as np
from PIL import Image, ImageOps
import tf_keras as tk

model = tk.models.load_model("keras_model.h5", compile=False)
class_names = open("labels.txt", "r").readlines()

np.set_printoptions(suppress=True)

data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)

image_path = r"D:\Downloads eadge\couleur-rhodesian-ridgeback-2727035_1920.jpg"
image = Image.open(image_path).convert("RGB")

size = (224, 224)
image = ImageOps.fit(image, size, Image.Resampling.BICUBIC)

image_array = np.asarray(image)
normalized_image_array = (image_array.astype(np.float32) / 127.5) - 1

data[0] = normalized_image_array

prediction = model.predict(data)
index = np.argmax(prediction)
class_name = class_names[index]
confidence_score = prediction[0][index]

print("-" * 30)
print(f"Result: {class_name.strip()}")
print(f"Confidence: {confidence_score:.2%}")
print("-" * 30)
# Out:
# WARNING:tensorflow:From D:\ai\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From D:\ai\Lib\site-packages\tf_keras\src\backend.py:1400: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From D:\ai\Lib\site-packages\tf_keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# 1/1 [==============================] - 1s 731ms/step
# ------------------------------
# Result: 1 Dog
# Confidence: 100.00%
# ------------------------------
